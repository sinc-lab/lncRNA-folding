# %% [markdown]
# # Standard packages

# %%
import os
import numpy as np
import pandas as pd
import time

# %% [markdown]
# # Specific installs

# %%
method_name = "RNAfold"

# %%
# !wget -q https://www.tbi.univie.ac.at/RNA/download/sourcecode/1_6_x/ViennaRNA-1.6.1.tar.gz
# !tar xfz ViennaRNA-1.6.1.tar.gz

# %%
install_path = "/content/ViennaRNA-1.6.1/Progs/"

# %cd /content/ViennaRNA-1.6.1
# !./configure 
# !make all
# (exit with 2 but RNAfold is compiled OK)
# %cd /content
# Out:
# /content/ViennaRNA-1.6.1
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking if malloc debugging is wanted... no
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking for gcc... gcc
# checking for C compiler default output file name... a.out
# checking whether the C compiler works... yes
# checking whether we are cross compiling... no
# checking for suffix of executables...
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ANSI C... none needed
# checking for style of include used by make... GNU
# checking dependency style of gcc... gcc3
# checking whether gcc accepts -fpic... yes
# checking for a BSD-compatible install... /usr/bin/install -c
# checking for ranlib... ranlib
# checking for perl... /usr/bin/perl
# checking how to run the C preprocessor... gcc -E
# checking for egrep... grep -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking malloc.h usability... yes
# checking malloc.h presence... yes
# checking for malloc.h... yes
# checking for strings.h... (cached) yes
# checking for unistd.h... (cached) yes
# checking for an ANSI C-conforming const... yes
# checking for size_t... yes
# checking for inline... inline
# checking for strdup... yes
# checking for strstr... yes
# checking for strchr... yes
# checking for erand48... yes
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating ViennaRNA.spec
# config.status: creating Utils/Makefile
# config.status: creating Progs/Makefile
# config.status: creating lib/Makefile
# config.status: creating man/Makefile
# config.status: creating Cluster/Makefile
# config.status: creating H/Makefile
# config.status: creating Perl/Makefile
# config.status: creating man/RNAheat.1
# config.status: creating man/RNAsubopt.1
# config.status: creating man/RNAdistance.1
# config.status: creating man/RNAinverse.1
# config.status: creating man/RNAeval.1
# config.status: creating man/RNAfold.1
# config.status: creating man/RNApdist.1
# config.status: creating man/RNAplot.1
# config.status: creating man/RNALfold.1
# config.status: creating man/RNAalifold.1
# config.status: creating man/RNAduplex.1
# config.status: creating man/RNAcofold.1
# config.status: creating man/RNAplfold.1
# config.status: creating config.h
# config.status: executing depfiles commands
# configure: configuring in RNAforester
# configure: running /bin/bash './configure' --prefix=/usr/local  --cache-file=/dev/null --srcdir=.
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking for g++... g++
# checking for C++ compiler default output file name... a.out
# checking whether the C++ compiler works... yes
# checking whether we are cross compiling... no
# checking for suffix of executables...
# checking for suffix of object files... o
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking for style of include used by make... GNU
# checking dependency style of g++... gcc3
# checking for gcc... gcc
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ANSI C... none needed
# checking dependency style of gcc... gcc3
# using (to be built) libRNA.a in ../lib
# checking for gdImageLine in -lgd... no
# checking how to run the C++ preprocessor... g++ -E
# checking for egrep... grep -E
# checking for ANSI C header files... no
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking g2.h usability... yes
# checking g2.h presence... yes
# checking for g2.h... yes
# checking for an ANSI C-conforming const... yes
# checking for inline... inline
# checking for size_t... yes
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating src/Makefile
# config.status: creating man/Makefile
# config.status: creating config.h
# config.status: executing depfiles commands
# configure: configuring in g2-0.70
# configure: running /bin/bash './configure' --prefix=/usr/local  '--prefix=/usr/local' '--cache-file=/dev/null' '--srcdir=.' --cache-file=/dev/null --srcdir=.
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking for gcc... gcc
# checking for C compiler default output file name... a.out
# checking whether the C compiler works... yes
# checking whether we are cross compiling... no
# checking for suffix of executables...
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ANSI C... none needed
# checking how to run the C preprocessor... gcc -E
# checking for g++... g++
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking for ranlib... ranlib
# checking for a BSD-compatible install... /usr/bin/install -c
# checking for find... find
# checking for makedepend... :
# checking for dlopen in -ldl... yes
# checking for X... libraries , headers
# checking for gethostbyname... yes
# checking for connect... yes
# checking for remove... yes
# checking for shmat... yes
# checking for IceConnectionNumber in -lICE... yes
# checking for main in -lm... yes
# checking for main in -lX11... yes
# checking for main in -lgd... no
# checking for egrep... grep -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking limits.h usability... yes
# checking limits.h presence... yes
# checking for limits.h... yes
#
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating demo/Makefile
# config.status: creating g2_perl/Makefile.PL
#
# Supported devices:
#     PostScript
#     FIG
#     X11
#
# Unsupported devices:
#     Win32
#     GD
#
# Run 'make depend' to create dependencies.
#
# configure: configuring in Kinfold
# configure: running /bin/bash './configure' --prefix=/usr/local  --cache-file=/dev/null --srcdir=.
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking if malloc debugging is wanted... no
# checking for gcc... gcc
# checking for C compiler default output file name... a.out
# checking whether the C compiler works... yes
# checking whether we are cross compiling... no
# checking for suffix of executables...
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ANSI C... none needed
# checking for style of include used by make... GNU
# checking dependency style of gcc... gcc3
# checking whether make sets $(MAKE)... (cached) yes
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking for ViennaRNA package...  headers in "../H" and library... "../lib"
# checking for exp in -lm... yes
# checking how to run the C preprocessor... gcc -E
# checking for egrep... grep -E
# checking for ANSI C header files... no
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking limits.h usability... yes
# checking limits.h presence... yes
# checking for limits.h... yes
# checking sys/time.h usability... yes
# checking sys/time.h presence... yes
# checking for sys/time.h... yes
# checking for unistd.h... (cached) yes
# checking fold.h usability... yes
# checking fold.h presence... yes
# checking for fold.h... yes
# checking for an ANSI C-conforming const... yes
# checking for strdup... no
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating Example/Makefile
# config.status: creating config.h
# config.status: executing depfiles commands
# configure:
# Configure successful with the following options:
#
#   Perl Extension:      yes
#   Analyse{Dists,Seqs}: no
#   Kinfold:             yes
#   RNAforester:         yes
#
# Files will be installed in the following directories:
#
#   Executables:  /usr/local/bin
#   Libraries:      /usr/local/lib
#   Header files: /usr/local/include
#   Extra Data:   /usr/local/share
#   Man pages:    /usr/local/man
#
# make  all-recursive
# make[1]: Entering directory '/content/ViennaRNA-1.6.1'
# Making all in lib
# make[2]: Entering directory '/content/ViennaRNA-1.6.1/lib'
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-dist_vars.o -MD -MP -MF ".deps/libRNA_a-dist_vars.Tpo" -c -o libRNA_a-dist_vars.o `test -f 'dist_vars.c' || echo './'`dist_vars.c; \
# then mv -f ".deps/libRNA_a-dist_vars.Tpo" ".deps/libRNA_a-dist_vars.Po"; else rm -f ".deps/libRNA_a-dist_vars.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-fold_vars.o -MD -MP -MF ".deps/libRNA_a-fold_vars.Tpo" -c -o libRNA_a-fold_vars.o `test -f 'fold_vars.c' || echo './'`fold_vars.c; \
# then mv -f ".deps/libRNA_a-fold_vars.Tpo" ".deps/libRNA_a-fold_vars.Po"; else rm -f ".deps/libRNA_a-fold_vars.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-part_func.o -MD -MP -MF ".deps/libRNA_a-part_func.Tpo" -c -o libRNA_a-part_func.o `test -f 'part_func.c' || echo './'`part_func.c; \
# then mv -f ".deps/libRNA_a-part_func.Tpo" ".deps/libRNA_a-part_func.Po"; else rm -f ".deps/libRNA_a-part_func.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-read_epars.o -MD -MP -MF ".deps/libRNA_a-read_epars.Tpo" -c -o libRNA_a-read_epars.o `test -f 'read_epars.c' || echo './'`read_epars.c; \
# then mv -f ".deps/libRNA_a-read_epars.Tpo" ".deps/libRNA_a-read_epars.Po"; else rm -f ".deps/libRNA_a-read_epars.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-treedist.o -MD -MP -MF ".deps/libRNA_a-treedist.Tpo" -c -o libRNA_a-treedist.o `test -f 'treedist.c' || echo './'`treedist.c; \
# then mv -f ".deps/libRNA_a-treedist.Tpo" ".deps/libRNA_a-treedist.Po"; else rm -f ".deps/libRNA_a-treedist.Tpo"; exit 1; fi
# treedist.c: In function ‘print_postorder_list’:
# treedist.c:437:13: warning: type defaults to ‘int’ in declaration of ‘i’ [-Wimplicit-int]
#     register i;
#              ^
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-energy_par.o -MD -MP -MF ".deps/libRNA_a-energy_par.Tpo" -c -o libRNA_a-energy_par.o `test -f 'energy_par.c' || echo './'`energy_par.c; \
# then mv -f ".deps/libRNA_a-energy_par.Tpo" ".deps/libRNA_a-energy_par.Po"; else rm -f ".deps/libRNA_a-energy_par.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-inverse.o -MD -MP -MF ".deps/libRNA_a-inverse.Tpo" -c -o libRNA_a-inverse.o `test -f 'inverse.c' || echo './'`inverse.c; \
# then mv -f ".deps/libRNA_a-inverse.Tpo" ".deps/libRNA_a-inverse.Po"; else rm -f ".deps/libRNA_a-inverse.Tpo"; exit 1; fi
# inverse.c: In function ‘pf_cost’:
# inverse.c:483:16: warning: passing argument 1 of ‘pf_fold’ discards ‘const’ qualifier from pointer target type [-Wdiscarded-qualifiers]
#     f = pf_fold(string, structure);
#                 ^~~~~~
# In file included from inverse.c:19:0:
# ../H/part_func.h:2:15: note: expected ‘char *’ but argument is of type ‘const char *’
#  extern float  pf_fold(char *sequence, char *structure);
#                ^~~~~~~
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-ProfileDist.o -MD -MP -MF ".deps/libRNA_a-ProfileDist.Tpo" -c -o libRNA_a-ProfileDist.o `test -f 'ProfileDist.c' || echo './'`ProfileDist.c; \
# then mv -f ".deps/libRNA_a-ProfileDist.Tpo" ".deps/libRNA_a-ProfileDist.Po"; else rm -f ".deps/libRNA_a-ProfileDist.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-RNAstruct.o -MD -MP -MF ".deps/libRNA_a-RNAstruct.Tpo" -c -o libRNA_a-RNAstruct.o `test -f 'RNAstruct.c' || echo './'`RNAstruct.c; \
# then mv -f ".deps/libRNA_a-RNAstruct.Tpo" ".deps/libRNA_a-RNAstruct.Po"; else rm -f ".deps/libRNA_a-RNAstruct.Tpo"; exit 1; fi
# RNAstruct.c: In function ‘b2HIT’:
# RNAstruct.c:99:21: warning: ‘%d’ directive writing between 1 and 10 bytes into a region of size 8 [-Wformat-overflow=]
#       sprintf(tt, "(U%d)" , u);
#                      ^~
# RNAstruct.c:99:18: note: directive argument in the range [0, 2147483647]
#       sprintf(tt, "(U%d)" , u);
#                   ^~~~~~~
# In file included from /usr/include/stdio.h:862:0,
#                  from RNAstruct.c:9:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:33:10: note: ‘__builtin___sprintf_chk’ output between 5 and 14 bytes into a destination of size 10
#    return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        __bos (__s), __fmt, __va_arg_pack ());
#        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# RNAstruct.c:108:21: warning: ‘%d’ directive writing between 1 and 10 bytes into a region of size 8 [-Wformat-overflow=]
#       sprintf(tt, "(U%d)" , u);
#                      ^~
# RNAstruct.c:108:18: note: directive argument in the range [0, 2147483647]
#       sprintf(tt, "(U%d)" , u);
#                   ^~~~~~~
# In file included from /usr/include/stdio.h:862:0,
#                  from RNAstruct.c:9:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:33:10: note: ‘__builtin___sprintf_chk’ output between 5 and 14 bytes into a destination of size 10
#    return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        __bos (__s), __fmt, __va_arg_pack ());
#        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# RNAstruct.c:117:21: warning: ‘%d’ directive writing between 1 and 10 bytes into a region of size 8 [-Wformat-overflow=]
#       sprintf(tt, "(U%d)" , u);
#                      ^~
# RNAstruct.c:117:18: note: directive argument in the range [0, 2147483647]
#       sprintf(tt, "(U%d)" , u);
#                   ^~~~~~~
# In file included from /usr/include/stdio.h:862:0,
#                  from RNAstruct.c:9:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:33:10: note: ‘__builtin___sprintf_chk’ output between 5 and 14 bytes into a destination of size 10
#    return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        __bos (__s), __fmt, __va_arg_pack ());
#        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# RNAstruct.c:122:16: warning: ‘%d’ directive writing between 1 and 10 bytes into a region of size 9 [-Wformat-overflow=]
#    sprintf(tt,"P%d)", p+1);
#                 ^~
# RNAstruct.c:122:14: note: directive argument in the range [1, 2147483647]
#    sprintf(tt,"P%d)", p+1);
#               ^~~~~~
# In file included from /usr/include/stdio.h:862:0,
#                  from RNAstruct.c:9:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:33:10: note: ‘__builtin___sprintf_chk’ output between 4 and 13 bytes into a destination of size 10
#    return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        __bos (__s), __fmt, __va_arg_pack ());
#        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# RNAstruct.c:131:22: warning: ‘%d’ directive writing between 1 and 10 bytes into a region of size 8 [-Wformat-overflow=]
#        sprintf(tt, "(U%d)" , u);
#                       ^~
# RNAstruct.c:131:19: note: directive argument in the range [0, 2147483647]
#        sprintf(tt, "(U%d)" , u);
#                    ^~~~~~~
# In file included from /usr/include/stdio.h:862:0,
#                  from RNAstruct.c:9:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:33:10: note: ‘__builtin___sprintf_chk’ output between 5 and 14 bytes into a destination of size 10
#    return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        __bos (__s), __fmt, __va_arg_pack ());
#        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-utils.o -MD -MP -MF ".deps/libRNA_a-utils.Tpo" -c -o libRNA_a-utils.o `test -f 'utils.c' || echo './'`utils.c; \
# then mv -f ".deps/libRNA_a-utils.Tpo" ".deps/libRNA_a-utils.Po"; else rm -f ".deps/libRNA_a-utils.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-fold.o -MD -MP -MF ".deps/libRNA_a-fold.Tpo" -c -o libRNA_a-fold.o `test -f 'fold.c' || echo './'`fold.c; \
# then mv -f ".deps/libRNA_a-fold.Tpo" ".deps/libRNA_a-fold.Po"; else rm -f ".deps/libRNA_a-fold.Tpo"; exit 1; fi
# fold.c:912:2: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#   P->mismatchI[type_2][sq1][sp1];
#   ^
# fold.c:911:17: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#        energy += P->mismatchI[type][si1][sj1]+
#                  ^
# fold.c:909:41: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#        energy += MIN2(MAX_NINIO, (nl-ns)*P->F_ninio[2]);
#                                          ^
# fold.c:67:45: note: in definition of macro ‘MIN2’
#  #define MIN2(A, B)      ((A) < (B) ? (A) : (B))
#                                              ^
# fold.c:909:41: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#        energy += MIN2(MAX_NINIO, (nl-ns)*P->F_ninio[2]);
#                                          ^
# fold.c:67:33: note: in definition of macro ‘MIN2’
#  #define MIN2(A, B)      ((A) < (B) ? (A) : (B))
#                                  ^
# fold.c:907:30: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#   (P->internal_loop[30]+(int)(P->lxc*log((n1+n2)/30.)));
#                               ^
# fold.c:907:3: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#   (P->internal_loop[30]+(int)(P->lxc*log((n1+n2)/30.)));
#    ^
# fold.c:906:34: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#        energy = (n1+n2<=MAXLOOP)?(P->internal_loop[n1+n2]):
#                                   ^
# fold.c:904:14: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#        return P->int22[type][type_2][si1][sp1][sq1][sj1];
#               ^
# fold.c:899:13: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#     energy = P->int21[type_2][type][sq1][si1][sp1];
#              ^
# fold.c:897:13: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#     energy = P->int21[type][type_2][si1][sq1][sj1];
#              ^
# fold.c:894:9: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#   return P->int11[type][type_2][si1][sj1];
#          ^
# fold.c:887:31: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#        if (type_2>2) energy += P->TerminalAU;
#                                ^
# fold.c:886:29: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#        if (type>2) energy += P->TerminalAU;
#                              ^
# fold.c:884:26: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#      if (nl==1) energy += P->stack[type][type_2];
#                           ^
# fold.c:883:27: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#        (P->bulge[30]+(int)(P->lxc*log(nl/30.)));
#                            ^
# fold.c:883:8: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#        (P->bulge[30]+(int)(P->lxc*log(nl/30.)));
#         ^
# fold.c:882:28: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#      energy = (nl<=MAXLOOP)?P->bulge[nl]:
#                             ^
# fold.c:879:12: warning: ‘P’ is static but used in inline function ‘LoopEnergy’ which is not static
#      return P->stack[type][type_2];    /* stack */
#             ^
# fold.c:821:15: warning: ‘P’ is static but used in inline function ‘HairpinE’ which is not static
#      energy += P->mismatchH[type][si1][sj1];
#                ^
# fold.c:818:17: warning: ‘P’ is static but used in inline function ‘HairpinE’ which is not static
#        energy += P->TerminalAU; /* penalty for closing AU GU pair */
#                  ^
# fold.c:815:36: warning: ‘P’ is static but used in inline function ‘HairpinE’ which is not static
#        energy += P->Triloop_E[(ts - P->Triloops)/6];
#                                     ^
# fold.c:815:17: warning: ‘P’ is static but used in inline function ‘HairpinE’ which is not static
#        energy += P->Triloop_E[(ts - P->Triloops)/6];
#                  ^
# fold.c:814:20: warning: ‘P’ is static but used in inline function ‘HairpinE’ which is not static
#      if ((ts=strstr(P->Triloops, tl)))
#                     ^
# fold.c:809:34: warning: ‘P’ is static but used in inline function ‘HairpinE’ which is not static
#   energy += P->TETRA_ENERGY[(ts - P->Tetraloops)/7];
#                                   ^
# fold.c:809:12: warning: ‘P’ is static but used in inline function ‘HairpinE’ which is not static
#   energy += P->TETRA_ENERGY[(ts - P->Tetraloops)/7];
#             ^
# fold.c:808:22: warning: ‘P’ is static but used in inline function ‘HairpinE’ which is not static
#        if ((ts=strstr(P->Tetraloops, tl)))
#                       ^
# fold.c:803:26: warning: ‘P’ is static but used in inline function ‘HairpinE’ which is not static
#      P->hairpin[30]+(int)(P->lxc*log((size)/30.));
#                           ^
# fold.c:803:5: warning: ‘P’ is static but used in inline function ‘HairpinE’ which is not static
#      P->hairpin[30]+(int)(P->lxc*log((size)/30.));
#      ^
# fold.c:802:27: warning: ‘P’ is static but used in inline function ‘HairpinE’ which is not static
#    energy = (size <= 30) ? P->hairpin[size] :
#                            ^
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-naview.o -MD -MP -MF ".deps/libRNA_a-naview.Tpo" -c -o libRNA_a-naview.o `test -f 'naview.c' || echo './'`naview.c; \
# then mv -f ".deps/libRNA_a-naview.Tpo" ".deps/libRNA_a-naview.Po"; else rm -f ".deps/libRNA_a-naview.Tpo"; exit 1; fi
# naview.c: In function ‘dump_loops’:
# naview.c:334:28: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long int’ [-Wformat=]
#    printf("\nRoot loop is #%d\n",(root-loops)+1);
#                            ~^    ~~~~~~~~~~~~~~
#                            %ld
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-PS_dot.o -MD -MP -MF ".deps/libRNA_a-PS_dot.Tpo" -c -o libRNA_a-PS_dot.o `test -f 'PS_dot.c' || echo './'`PS_dot.c; \
# then mv -f ".deps/libRNA_a-PS_dot.Tpo" ".deps/libRNA_a-PS_dot.Po"; else rm -f ".deps/libRNA_a-PS_dot.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-stringdist.o -MD -MP -MF ".deps/libRNA_a-stringdist.Tpo" -c -o libRNA_a-stringdist.o `test -f 'stringdist.c' || echo './'`stringdist.c; \
# then mv -f ".deps/libRNA_a-stringdist.Tpo" ".deps/libRNA_a-stringdist.Po"; else rm -f ".deps/libRNA_a-stringdist.Tpo"; exit 1; fi
# stringdist.c:24:0: warning: "INFINITY" redefined
#  #define INFINITY       10000
#
# In file included from stringdist.c:12:0:
# /usr/include/math.h:91:0: note: this is the location of the previous definition
#  #  define INFINITY (__builtin_inff ())
#
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-params.o -MD -MP -MF ".deps/libRNA_a-params.Tpo" -c -o libRNA_a-params.o `test -f 'params.c' || echo './'`params.c; \
# then mv -f ".deps/libRNA_a-params.Tpo" ".deps/libRNA_a-params.Po"; else rm -f ".deps/libRNA_a-params.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-subopt.o -MD -MP -MF ".deps/libRNA_a-subopt.Tpo" -c -o libRNA_a-subopt.o `test -f 'subopt.c' || echo './'`subopt.c; \
# then mv -f ".deps/libRNA_a-subopt.Tpo" ".deps/libRNA_a-subopt.Po"; else rm -f ".deps/libRNA_a-subopt.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-list.o -MD -MP -MF ".deps/libRNA_a-list.Tpo" -c -o libRNA_a-list.o `test -f 'list.c' || echo './'`list.c; \
# then mv -f ".deps/libRNA_a-list.Tpo" ".deps/libRNA_a-list.Po"; else rm -f ".deps/libRNA_a-list.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-Lfold.o -MD -MP -MF ".deps/libRNA_a-Lfold.Tpo" -c -o libRNA_a-Lfold.o `test -f 'Lfold.c' || echo './'`Lfold.c; \
# then mv -f ".deps/libRNA_a-Lfold.Tpo" ".deps/libRNA_a-Lfold.Po"; else rm -f ".deps/libRNA_a-Lfold.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-cofold.o -MD -MP -MF ".deps/libRNA_a-cofold.Tpo" -c -o libRNA_a-cofold.o `test -f 'cofold.c' || echo './'`cofold.c; \
# then mv -f ".deps/libRNA_a-cofold.Tpo" ".deps/libRNA_a-cofold.Po"; else rm -f ".deps/libRNA_a-cofold.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-part_func_co.o -MD -MP -MF ".deps/libRNA_a-part_func_co.Tpo" -c -o libRNA_a-part_func_co.o `test -f 'part_func_co.c' || echo './'`part_func_co.c; \
# then mv -f ".deps/libRNA_a-part_func_co.Tpo" ".deps/libRNA_a-part_func_co.Po"; else rm -f ".deps/libRNA_a-part_func_co.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-ProfileAln.o -MD -MP -MF ".deps/libRNA_a-ProfileAln.Tpo" -c -o libRNA_a-ProfileAln.o `test -f 'ProfileAln.c' || echo './'`ProfileAln.c; \
# then mv -f ".deps/libRNA_a-ProfileAln.Tpo" ".deps/libRNA_a-ProfileAln.Po"; else rm -f ".deps/libRNA_a-ProfileAln.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-duplex.o -MD -MP -MF ".deps/libRNA_a-duplex.Tpo" -c -o libRNA_a-duplex.o `test -f 'duplex.c' || echo './'`duplex.c; \
# then mv -f ".deps/libRNA_a-duplex.Tpo" ".deps/libRNA_a-duplex.Po"; else rm -f ".deps/libRNA_a-duplex.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-alifold.o -MD -MP -MF ".deps/libRNA_a-alifold.Tpo" -c -o libRNA_a-alifold.o `test -f 'alifold.c' || echo './'`alifold.c; \
# then mv -f ".deps/libRNA_a-alifold.Tpo" ".deps/libRNA_a-alifold.Po"; else rm -f ".deps/libRNA_a-alifold.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-alipfold.o -MD -MP -MF ".deps/libRNA_a-alipfold.Tpo" -c -o libRNA_a-alipfold.o `test -f 'alipfold.c' || echo './'`alipfold.c; \
# then mv -f ".deps/libRNA_a-alipfold.Tpo" ".deps/libRNA_a-alipfold.Po"; else rm -f ".deps/libRNA_a-alipfold.Tpo"; exit 1; fi
# alipfold.c: In function ‘alipf_fold’:
# alipfold.c:98:40: warning: passing argument 2 of ‘make_pscores’ from incompatible pointer type [-Wincompatible-pointer-types]
#    make_pscores((const short *const*)S, sequences, n_seq, structure);
#                                         ^~~~~~~~~
# alipfold.c:42:14: note: expected ‘const char * const*’ but argument is of type ‘char **’
#  PRIVATE void make_pscores(const short *const *S, const char *const* AS,
#               ^~~~~~~~~~~~
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-aln_util.o -MD -MP -MF ".deps/libRNA_a-aln_util.Tpo" -c -o libRNA_a-aln_util.o `test -f 'aln_util.c' || echo './'`aln_util.c; \
# then mv -f ".deps/libRNA_a-aln_util.Tpo" ".deps/libRNA_a-aln_util.Po"; else rm -f ".deps/libRNA_a-aln_util.Tpo"; exit 1; fi
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -fpic -g -O2 -MT libRNA_a-LPfold.o -MD -MP -MF ".deps/libRNA_a-LPfold.Tpo" -c -o libRNA_a-LPfold.o `test -f 'LPfold.c' || echo './'`LPfold.c; \
# then mv -f ".deps/libRNA_a-LPfold.Tpo" ".deps/libRNA_a-LPfold.Po"; else rm -f ".deps/libRNA_a-LPfold.Tpo"; exit 1; fi
# rm -f libRNA.a
# ar cru libRNA.a libRNA_a-dist_vars.o libRNA_a-fold_vars.o libRNA_a-part_func.o libRNA_a-read_epars.o libRNA_a-treedist.o libRNA_a-energy_par.o libRNA_a-inverse.o libRNA_a-ProfileDist.o libRNA_a-RNAstruct.o libRNA_a-utils.o libRNA_a-fold.o libRNA_a-naview.o libRNA_a-PS_dot.o libRNA_a-stringdist.o libRNA_a-params.o libRNA_a-subopt.o libRNA_a-list.o libRNA_a-Lfold.o libRNA_a-cofold.o libRNA_a-part_func_co.o libRNA_a-ProfileAln.o libRNA_a-duplex.o libRNA_a-alifold.o libRNA_a-alipfold.o libRNA_a-aln_util.o libRNA_a-LPfold.o
# ar: `u' modifier ignored since `D' is the default (see `U')
# ranlib libRNA.a
# make[2]: Leaving directory '/content/ViennaRNA-1.6.1/lib'
# Making all in Progs
# make[2]: Entering directory '/content/ViennaRNA-1.6.1/Progs'
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -g -O2 -MT RNAfold.o -MD -MP -MF ".deps/RNAfold.Tpo" -c -o RNAfold.o RNAfold.c; \
# then mv -f ".deps/RNAfold.Tpo" ".deps/RNAfold.Po"; else rm -f ".deps/RNAfold.Tpo"; exit 1; fi
# gcc  -g -O2   -o RNAfold  RNAfold.o ../lib/libRNA.a -lm
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -g -O2 -MT RNAeval.o -MD -MP -MF ".deps/RNAeval.Tpo" -c -o RNAeval.o RNAeval.c; \
# then mv -f ".deps/RNAeval.Tpo" ".deps/RNAeval.Po"; else rm -f ".deps/RNAeval.Tpo"; exit 1; fi
# gcc  -g -O2   -o RNAeval  RNAeval.o ../lib/libRNA.a -lm
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -g -O2 -MT RNAheat.o -MD -MP -MF ".deps/RNAheat.Tpo" -c -o RNAheat.o RNAheat.c; \
# then mv -f ".deps/RNAheat.Tpo" ".deps/RNAheat.Po"; else rm -f ".deps/RNAheat.Tpo"; exit 1; fi
# gcc  -g -O2   -o RNAheat  RNAheat.o ../lib/libRNA.a -lm
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -g -O2 -MT RNApdist.o -MD -MP -MF ".deps/RNApdist.Tpo" -c -o RNApdist.o RNApdist.c; \
# then mv -f ".deps/RNApdist.Tpo" ".deps/RNApdist.Po"; else rm -f ".deps/RNApdist.Tpo"; exit 1; fi
# gcc  -g -O2   -o RNApdist  RNApdist.o ../lib/libRNA.a -lm
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -g -O2 -MT RNAdistance.o -MD -MP -MF ".deps/RNAdistance.Tpo" -c -o RNAdistance.o RNAdistance.c; \
# then mv -f ".deps/RNAdistance.Tpo" ".deps/RNAdistance.Po"; else rm -f ".deps/RNAdistance.Tpo"; exit 1; fi
# gcc  -g -O2   -o RNAdistance  RNAdistance.o ../lib/libRNA.a -lm
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -g -O2 -MT RNAinverse.o -MD -MP -MF ".deps/RNAinverse.Tpo" -c -o RNAinverse.o RNAinverse.c; \
# then mv -f ".deps/RNAinverse.Tpo" ".deps/RNAinverse.Po"; else rm -f ".deps/RNAinverse.Tpo"; exit 1; fi
# RNAinverse.c:31:0: warning: "INFINITY" redefined
#  #define  INFINITY        100000
#
# In file included from RNAinverse.c:9:0:
# /usr/include/math.h:91:0: note: this is the location of the previous definition
#  #  define INFINITY (__builtin_inff ())
#
# gcc  -g -O2   -o RNAinverse  RNAinverse.o ../lib/libRNA.a -lm
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -g -O2 -MT RNAplot.o -MD -MP -MF ".deps/RNAplot.Tpo" -c -o RNAplot.o RNAplot.c; \
# then mv -f ".deps/RNAplot.Tpo" ".deps/RNAplot.Po"; else rm -f ".deps/RNAplot.Tpo"; exit 1; fi
# gcc  -g -O2   -o RNAplot  RNAplot.o ../lib/libRNA.a -lm
# if gcc -DHAVE_CONFIG_H -I. -I. -I.. -I../H    -g -O2 -MT RNAsubopt.o -MD -MP -MF ".deps/RNAsubopt.Tpo" -c -o RNAsubopt.o RNAsubopt.c; \
# then mv -f ".deps/RNAsubopt.Tpo" ".deps/RNAsubopt.Po"; else rm -f ".deps/RNAsubopt.Tpo"; exit 1; fi
# gcc  -g -O2   -o RNAsubopt  RNAsubopt.o ../lib/libRNA.a -lm
# ../lib/libRNA.a(libRNA_a-subopt.o): In function `repeat':
# /content/ViennaRNA-1.6.1/lib/subopt.c:855: undefined reference to `LoopEnergy'
# /content/ViennaRNA-1.6.1/lib/subopt.c:828: undefined reference to `LoopEnergy'
# /content/ViennaRNA-1.6.1/lib/subopt.c:914: undefined reference to `HairpinE'
# collect2: error: ld returned 1 exit status
# Makefile:320: recipe for target 'RNAsubopt' failed
# make[2]: *** [RNAsubopt] Error 1
# make[2]: Leaving directory '/content/ViennaRNA-1.6.1/Progs'
# Makefile:270: recipe for target 'all-recursive' failed
# make[1]: *** [all-recursive] Error 1
# make[1]: Leaving directory '/content/ViennaRNA-1.6.1'
# Makefile:189: recipe for target 'all' failed
# make: *** [all] Error 2
# /content

# %% [markdown]
# # S. cerevisiae (sce) 18 long non-coding RNA dataset
# Data source: https://genie.weizmann.ac.il/pubs/PARS10/data/sce_genes_folded.tab.gz

# %%
gh_path = "https://raw.githubusercontent.com/sinc-lab/lncRNA-folding/master/data/"
sce = pd.read_csv(gh_path + "sce_genes_folded.tab", delimiter='\t', 
                  header=None, index_col=0, 
                  names=("Gene ID", "sequence", "PARS-assisted folding"))

# %%
# Sequences to process
yeast18lnc = ["snR81", "snR34", "snR43", "snR44",  "snR31",  "snR10",
              "snR63", "snR11", "snR82", "snR17b", "snR17a", "snR37",
              "SCR1",  "SRG1",  "snR19", "snR30",  "LSR1",   "TLC1"]

# %%
# Scores for constraints
pars = pd.read_csv(gh_path + "sce_PARS_score.tab", sep='\t').set_index('gene')

# %% [markdown]
# # Compute structures

# %%
def run_folding(fasta_name):

    # Compute structure
    command_line = [install_path + "RNAfold ",  
                    "-T 37 ",
                    "-C ",  
                    "< tmp.fasta > rnafold_tmp.fasta"]
    # !{"".join(command_line)}
    
    
    return "rnafold_tmp.fasta"

# %%
# !/content/ViennaRNA-1.6.1/Progs/RNAfold -h
# Out:
# usage:
# RNAfold [-p[0]] [-C] [-T temp] [-4] [-d[2|3]] [-noGU] [-noCloseGU]
#         [-noLP] [-e e_set] [-P paramfile] [-nsp pairs] [-S scale]
#         [-noconv] [-circ]

# %%
# Convert scores to contraints with RNAfold 1.6 format
# https://genie.weizmann.ac.il/pubs/PARS10/pars10_notes.html
def get_constraints(pars, lnc):
    scores = np.array(pars.loc[lnc, 'score'].split(';'), dtype=float)
    cons = ["."]*len(scores)
    for i,s in enumerate(scores):
        if s>5: cons[i] = "|"
        elif s<-5: cons[i] = "x"
    cons_str = "".join(cons)
    return cons_str
    
# Get prediction in a string to compare with PARS assited references
def get_pred(file_name, slen):
    str_out = ""
    with open(file_name,'r') as fasta:
        for i, line in enumerate(fasta):
            if i==2: str_out = line[:slen]
    return str_out

# %%
out_fasta_name = method_name + "_yeast18"
if os.path.exists(out_fasta_name + ".fasta"): os.remove(out_fasta_name + ".fasta")

lnc_ids = yeast18lnc
print("   \t lnc \t len \t time \t =ref(Kertesz2010)?")
for i, lnc in enumerate(lnc_ids): 

    start_time = time.time()
    seq = sce.loc[lnc]["sequence"]
    print(f"{i+1}/{len(lnc_ids)}\t{lnc} \t {len(seq)}", end='\t')

    cons = get_constraints(pars, lnc)
    #print("Con: \n", cons)

    # Write a one-sequence fasta
    with open("tmp.fasta", "w") as ofile: 
        ofile.write(f">{lnc}\n{seq}\n{cons}\n")

    dot_file_name = run_folding("tmp.fasta")

    # Concatenate outputs
    os.system("cat " + dot_file_name + " >> " + out_fasta_name + ".fasta") 

    print(f"{time.time() - start_time: .1f} s", end='\t')

    str_ref = sce.loc[lnc]["PARS-assisted folding"]
    str_pre = get_pred(dot_file_name, len(seq))
    if not (str_ref==str_pre):  
        print("Ref: \n" + str_ref)
        print("Pre: \n" + str_pre)
    else:
        print("  OK")
# Out:
#    	 lnc 	 len 	 time 	 =ref(Kertesz2010)?
# 1/18	snR81 	 201	 0.1 s	  OK
# 2/18	snR34 	 203	 0.1 s	  OK
# 3/18	snR43 	 209	 0.1 s	  OK
# 4/18	snR44 	 211	 0.1 s	  OK
# 5/18	snR31 	 225	 0.1 s	  OK
# 6/18	snR10 	 245	 0.1 s	  OK
# 7/18	snR63 	 255	 0.1 s	  OK
# 8/18	snR11 	 258	 0.2 s	  OK
# 9/18	snR82 	 268	 0.1 s	  OK
# 10/18	snR17b 	 332	 0.2 s	  OK
# 11/18	snR17a 	 333	 0.2 s	  OK
# 12/18	snR37 	 386	 0.2 s	  OK
# 13/18	SCR1 	 522	 0.3 s	  OK
# 14/18	SRG1 	 551	 0.3 s	  OK
# 15/18	snR19 	 568	 0.4 s	  OK
# 16/18	snR30 	 606	 0.4 s	  OK
# 17/18	LSR1 	 1175	 1.8 s	  OK
# 18/18	TLC1 	 1301	 2.1 s	  OK
